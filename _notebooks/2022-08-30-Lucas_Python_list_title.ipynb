# %% [markdown]
# # InfoDb
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Lucas Moore
# - categories: [fastpages, python]
#
# InfoDb is a type of data structure that holds infomation and key details. This is a test in order to use InfoDb and to understand how to organize the output text. The code below includes infomation on 4 people and outputs them below the code. Each person's set of infomation is given their own record that is outputed 4 ways using different code. The 4 ways are, standard print, for loop with Index, while loop, and Recursion loop.

# %% [markdown]
# Standard Print:
# --
# Standard Print is only using the command print(InfoDb) to display InfoDb. This code doesn't separate the infomation very neatly.

# %%
# Define an empty List called InfoDb
InfoDb = []

# InfoDB is a data structure with expected Keys and Values

# Append to List a Dictionary of key/values related to a person and cars
InfoDb.append({
    "FirstName": "John",
    "LastName": "Mortensen",
    "DOB": "October 21",
    "Residence": "San Diego",
    "Email": "jmortensen@powayusd.com",
    "Owns_Cars": ["2015-Fusion", "2011-Ranger", "2003-Excursion", "1997-F350", "1969-Cadillac"]
})



# Append to List a 2nd Dictionary of key/values
InfoDb.append({
    "FirstName": "Sunny",
    "LastName": "Naidu",
    "DOB": "August 2",
    "Residence": "Temecula",
    "Email": "snaidu@powayusd.com",
    "Owns_Cars": ["4Runner"]
    
})


# Personal Info
InfoDb.append({
    "FirstName": "Lucas",
    "LastName": "Moore",
    "DOB": "Decemeber 16",
    "Residence": "4S Ranch",
    "Email": "lem16silver@gmail.com",
    "Owns_Cars": ["None"]
    
})

InfoDb.append({
    "FirstName": "Aniket",
    "LastName": "Chakrado",
    "DOB": "Febuary 20",
    "Residence": "4S Ranch",
    "Email": "aniket@charadeo.net",
    "Owns_Cars": ["Red-Buggati"]
    
})
# Print data structure
print(InfoDb)
# Out:
# [{'FirstName': 'John', 'LastName': 'Mortensen', 'DOB': 'October 21', 'Residence': 'San Diego', 'Email': 'jmortensen@powayusd.com', 'Owns_Cars': ['2015-Fusion', '2011-Ranger', '2003-Excursion', '1997-F350', '1969-Cadillac']}, {'FirstName': 'Sunny', 'LastName': 'Naidu', 'DOB': 'August 2', 'Residence': 'Temecula', 'Email': 'snaidu@powayusd.com', 'Owns_Cars': ['4Runner']}, {'FirstName': 'Lucas', 'LastName': 'Moore', 'DOB': 'Decemeber 16', 'Residence': '4S Ranch', 'Email': 'lem16silver@gmail.com', 'Owns_Cars': ['None']}, {'FirstName': 'Aniket', 'LastName': 'Chakrado', 'DOB': 'Febuary 20', 'Residence': '4S Ranch', 'Email': 'aniket@charadeo.net', 'Owns_Cars': ['Red-Buggati']}]

# %% [markdown]
# InfoDb For loop with Index output:
# --
# For loop results in the InfoDb becoming organized by their stand alone records. It creates the same output as InfoDb while loop and InfoDb recursion loop.

# %%
# Define an empty List called InfoDb
InfoDb = []

# InfoDB is a data structure with expected Keys and Values

# Append to List a Dictionary of key/values related to a person and cars
InfoDb.append({
    "FirstName": "John",
    "LastName": "Mortensen",
    "DOB": "October 21",
    "Residence": "San Diego",
    "Email": "jmortensen@powayusd.com",
    "Owns_Cars": ["2015-Fusion", "2011-Ranger", "2003-Excursion", "1997-F350", "1969-Cadillac"]
})



# Append to List a 2nd Dictionary of key/values
InfoDb.append({
    "FirstName": "Sunny",
    "LastName": "Naidu",
    "DOB": "August 2",
    "Residence": "Temecula",
    "Email": "snaidu@powayusd.com",
    "Owns_Cars": ["4Runner"]
    
})


# Personal Info
InfoDb.append({
    "FirstName": "Lucas",
    "LastName": "Moore",
    "DOB": "Decemeber 16",
    "Residence": "4S Ranch",
    "Email": "lem16silver@gmail.com",
    "Owns_Cars": ["None"]
    
})

InfoDb.append({
    "FirstName": "Aniket",
    "LastName": "Chakrado",
    "DOB": "Febuary 20",
    "Residence": "4S Ranch",
    "Email": "aniket@charadeo.net",
    "Owns_Cars": ["Red-Buggati"]
    
})
# Print the data structure
#print(InfoDb)

def print_data(d_rec):
    print(d_rec["FirstName"], d_rec["LastName"])  # using comma puts space between values
    print("\t", "Residence:", d_rec["Residence"]) # \t is a tab indent
    print("\t", "Birth Day:", d_rec["DOB"])
    print("\t", "Cars: ", end="")  # end="" make sure no return occurs
    print(", ".join(d_rec["Owns_Cars"]))  # join allows printing a string list with separator
    print()

    # for loop algorithm iterates on length of InfoDb
def for_loop():
    print("For loop output\n")
    for record in InfoDb:
        print_data(record)

for_loop()
# Out:
# For loop output
#
# John Mortensen
# 	 Residence: San Diego
# 	 Birth Day: October 21
# 	 Cars: 2015-Fusion, 2011-Ranger, 2003-Excursion, 1997-F350, 1969-Cadillac
#
# Sunny Naidu
# 	 Residence: Temecula
# 	 Birth Day: August 2
# 	 Cars: 4Runner
#
# Lucas Moore
# 	 Residence: 4S Ranch
# 	 Birth Day: Decemeber 16
# 	 Cars: None
#
# Aniket Chakrado
# 	 Residence: 4S Ranch
# 	 Birth Day: Febuary 20
# 	 Cars: Red-Buggati

# %% [markdown]
# InfoDb while loop output:
# --
# While loop results in the InfoDb becoming organized by their stand alone records. It creates the same output as InfoDb for loop with index and InfoDb recursion loop.

# %%
# Define an empty List called InfoDb
InfoDb = []

# InfoDB is a data structure with expected Keys and Values

# Append to List a Dictionary of key/values related to a person and cars
InfoDb.append({
    "FirstName": "John",
    "LastName": "Mortensen",
    "DOB": "October 21",
    "Residence": "San Diego",
    "Email": "jmortensen@powayusd.com",
    "Owns_Cars": ["2015-Fusion", "2011-Ranger", "2003-Excursion", "1997-F350", "1969-Cadillac"]
})



# Append to List a 2nd Dictionary of key/values
InfoDb.append({
    "FirstName": "Sunny",
    "LastName": "Naidu",
    "DOB": "August 2",
    "Residence": "Temecula",
    "Email": "snaidu@powayusd.com",
    "Owns_Cars": ["4Runner"]
    
})


# Personal Info
InfoDb.append({
    "FirstName": "Lucas",
    "LastName": "Moore",
    "DOB": "Decemeber 16",
    "Residence": "4S Ranch",
    "Email": "lem16silver@gmail.com",
    "Owns_Cars": ["None"]
    
})

InfoDb.append({
    "FirstName": "Aniket",
    "LastName": "Chakrado",
    "DOB": "Febuary 20",
    "Residence": "4S Ranch",
    "Email": "aniket@charadeo.net",
    "Owns_Cars": ["Red-Buggati"]
    
})
# Print the data structure
#print(InfoDb)

def print_data(d_rec):
    print(d_rec["FirstName"], d_rec["LastName"])  # using comma puts space between values
    print("\t", "Residence:", d_rec["Residence"]) # \t is a tab indent
    print("\t", "Birth Day:", d_rec["DOB"])
    print("\t", "Cars: ", end="")  # end="" make sure no return occurs
    print(", ".join(d_rec["Owns_Cars"]))  # join allows printing a string list with separator
    print()

    # while loop algorithm contains an initial n and an index incrementing statement (n += 1)
def while_loop():
    print("While loop output\n")
    i = 0
    while i < len(InfoDb):
        record = InfoDb[i]
        print_data(record)
        i += 1
    return

while_loop()
# Out:
# While loop output
#
# John Mortensen
# 	 Residence: San Diego
# 	 Birth Day: October 21
# 	 Cars: 2015-Fusion, 2011-Ranger, 2003-Excursion, 1997-F350, 1969-Cadillac
#
# Sunny Naidu
# 	 Residence: Temecula
# 	 Birth Day: August 2
# 	 Cars: 4Runner
#
# Lucas Moore
# 	 Residence: 4S Ranch
# 	 Birth Day: Decemeber 16
# 	 Cars: None
#
# Aniket Chakrado
# 	 Residence: 4S Ranch
# 	 Birth Day: Febuary 20
# 	 Cars: Red-Buggati

# %% [markdown]
# InfoDb recursion loop output:
# --
# Recursion loop results in the InfoDb becoming organized by their stand alone records. It creates the same output as InfoDb for loop with index and InfoDb while loop.

# %%
# Define an empty List called InfoDb
InfoDb = []

# InfoDB is a data structure with expected Keys and Values

# Append to List a Dictionary of key/values related to a person and cars
InfoDb.append({
    "FirstName": "John",
    "LastName": "Mortensen",
    "DOB": "October 21",
    "Residence": "San Diego",
    "Email": "jmortensen@powayusd.com",
    "Owns_Cars": ["2015-Fusion", "2011-Ranger", "2003-Excursion", "1997-F350", "1969-Cadillac"]
})



# Append to List a 2nd Dictionary of key/values
InfoDb.append({
    "FirstName": "Sunny",
    "LastName": "Naidu",
    "DOB": "August 2",
    "Residence": "Temecula",
    "Email": "snaidu@powayusd.com",
    "Owns_Cars": ["4Runner"]
    
})


# Personal Info
InfoDb.append({
    "FirstName": "Lucas",
    "LastName": "Moore",
    "DOB": "Decemeber 16",
    "Residence": "4S Ranch",
    "Email": "lem16silver@gmail.com",
    "Owns_Cars": ["None"]
    
})

InfoDb.append({
    "FirstName": "Aniket",
    "LastName": "Chakrado",
    "DOB": "Febuary 20",
    "Residence": "4S Ranch",
    "Email": "aniket@charadeo.net",
    "Owns_Cars": ["Red-Buggati"]
    
})
# Print the data structure
#print(InfoDb)

def print_data(d_rec):
    print(d_rec["FirstName"], d_rec["LastName"])  # using comma puts space between values
    print("\t", "Residence:", d_rec["Residence"]) # \t is a tab indent
    print("\t", "Birth Day:", d_rec["DOB"])
    print("\t", "Cars: ", end="")  # end="" make sure no return occurs
    print(", ".join(d_rec["Owns_Cars"]))  # join allows printing a string list with separator
    print()

    # recursion algorithm loops incrementing on each call (n + 1) until exit condition is met
def recursive_loop(i):
    if i < len(InfoDb):
        record = InfoDb[i]
        print_data(record)
        recursive_loop(i + 1)
    return
    
print("Recursive loop output\n")
recursive_loop(0)
# Out:
# Recursive loop output
#
# John Mortensen
# 	 Residence: San Diego
# 	 Birth Day: October 21
# 	 Cars: 2015-Fusion, 2011-Ranger, 2003-Excursion, 1997-F350, 1969-Cadillac
#
# Sunny Naidu
# 	 Residence: Temecula
# 	 Birth Day: August 2
# 	 Cars: 4Runner
#
# Lucas Moore
# 	 Residence: 4S Ranch
# 	 Birth Day: Decemeber 16
# 	 Cars: None
#
# Aniket Chakrado
# 	 Residence: 4S Ranch
# 	 Birth Day: Febuary 20
# 	 Cars: Red-Buggati
